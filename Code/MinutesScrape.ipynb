# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)

import os
output_dir = '/content/drive/MyDrive/Minutes'

# Create the directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

os.chdir(output_dir)

# Verify the current working directory
print(f"Current working directory: {os.getcwd()}")
# Out:
# Mounted at /content/drive
# Current working directory: /content/drive/MyDrive/Minutes

# %%
# !cd /tmp && pip install beautifulsoup4 html5lib python-dateutil requests pandas
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (1.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.12/dist-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib) (0.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)

# %%
# Scrape minutes
import pandas as pd
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import os
import time
from google.colab import drive
import re
import uuid
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import csv
import sys

# Mount Google Drive
drive.mount('/content/drive')
output_dir = '/content/drive/MyDrive/Minutes'
os.makedirs(output_dir, exist_ok=True)

# Increase CSV field size limit for very long FOMC minutes
csv.field_size_limit(sys.maxsize)

# Hardcoded list of FOMC meeting dates from 2000 to January 2025
fomc_dates = [
    # 2000
    '2000-02-02', '2000-03-21', '2000-05-16', '2000-06-28', '2000-08-22', '2000-10-03', '2000-11-15', '2000-12-19',
    # 2001
    '2001-01-31', '2001-03-20', '2001-05-15', '2001-06-27', '2001-08-21', '2001-10-02', '2001-11-06', '2001-12-11',
    # 2002
    '2002-01-30', '2002-03-19', '2002-05-07', '2002-06-26', '2002-08-13', '2002-09-24', '2002-11-06', '2002-12-10',
    # 2003
    '2003-01-29', '2003-03-18', '2003-05-06', '2003-06-25', '2003-08-12', '2003-09-16', '2003-10-28', '2003-12-09',
    # 2004
    '2004-01-28', '2004-03-16', '2004-05-04', '2004-06-30', '2004-08-10', '2004-09-21', '2004-11-10', '2004-12-14',
    # 2005
    '2005-02-02', '2005-03-22', '2005-05-03', '2005-06-30', '2005-08-09', '2005-09-20', '2005-11-01', '2005-12-13',
    # 2006
    '2006-01-31', '2006-03-28', '2006-05-10', '2006-06-29', '2006-08-08', '2006-09-20', '2006-10-25', '2006-12-12',
    # 2007
    '2007-01-31', '2007-03-21', '2007-05-09', '2007-06-28', '2007-08-07', '2007-09-18', '2007-10-31', '2007-12-11',
    # 2008
    '2008-01-30', '2008-03-18', '2008-04-30', '2008-06-25', '2008-08-05', '2008-09-16', '2008-10-29', '2008-12-16',
    # 2009
    '2009-01-28', '2009-03-18', '2009-04-29', '2009-06-24', '2009-08-12', '2009-09-23', '2009-11-04', '2009-12-16',
    # 2010
    '2010-01-27', '2010-03-16', '2010-04-28', '2010-06-23', '2010-08-10', '2010-09-21', '2010-11-03', '2010-12-14',
    # 2011
    '2011-01-26', '2011-03-15', '2011-04-27', '2011-06-22', '2011-08-09', '2011-09-21', '2011-11-02', '2011-12-13',
    # 2012
    '2012-01-25', '2012-03-13', '2012-04-25', '2012-06-20', '2012-08-01', '2012-09-13', '2012-12-12',
    # 2013
    '2013-03-20', '2013-05-01', '2013-06-19', '2013-07-31', '2013-09-18', '2013-10-30', '2013-12-18',
    # 2014
    '2014-01-29', '2014-03-19', '2014-04-30', '2014-06-18', '2014-07-30', '2014-09-17', '2014-10-29', '2014-12-17',
    # 2015
    '2015-01-28', '2015-03-18', '2015-04-29', '2015-06-17', '2015-07-29', '2015-09-17', '2015-10-28', '2015-12-16',
    # 2016
    '2016-01-27', '2016-03-16', '2016-04-27', '2016-06-15', '2016-07-27', '2016-09-21', '2016-11-02', '2016-12-14',
    # 2017
    '2017-02-01', '2017-03-15', '2017-05-03', '2017-06-14', '2017-07-26', '2017-09-20', '2017-11-01', '2017-12-13',
    # 2018
    '2018-01-31', '2018-03-21', '2018-05-02', '2018-06-13', '2018-08-01', '2018-09-26', '2018-11-08', '2018-12-19',
    # 2019
    '2019-01-30', '2019-03-20', '2019-05-01', '2019-06-19', '2019-07-31', '2019-09-18', '2019-10-30', '2019-12-11',
    # 2020
    '2020-01-29', '2020-03-15', '2020-04-29', '2020-06-10', '2020-07-29', '2020-09-16', '2020-11-05', '2020-12-16',
    # 2021
    '2021-01-27', '2021-03-17', '2021-04-28', '2021-06-16', '2021-07-28', '2021-09-22', '2021-11-03', '2021-12-15',
    # 2022
    '2022-01-26', '2022-03-16', '2022-05-04', '2022-06-15', '2022-07-27', '2022-09-21', '2022-11-02', '2022-12-14',
    # 2023
    '2023-02-01', '2023-03-22', '2023-05-03', '2023-06-14', '2023-07-26', '2023-09-20', '2023-11-01', '2023-12-13',
    # 2024
    '2024-01-31', '2024-03-20', '2024-05-01', '2024-06-12', '2024-07-31', '2024-09-18', '2024-11-07', '2024-12-18',
    # 2025
    '2025-01-29'
]

# TOGGLE TO DEBUG
years_to_process = None  # Change to desired year(s), e.g., [2000] or [2024, 2025], or None for all
if years_to_process is not None:
    fomc_dates = [date for date in fomc_dates if int(date.split('-')[0]) in years_to_process]
    print(f"Filtering to process only years: {years_to_process}")
else:
    print("Processing all available years")

# Filter dates to ensure they are on or before the current date (September 18, 2025)
current_date = datetime(2025, 9, 18)
fomc_dates = [date for date in fomc_dates if datetime.strptime(date, '%Y-%m-%d') <= current_date]

# Load existing CSV if it exists
csv_path = os.path.join(output_dir, 'fomc_minutes.csv')
existing_dates = set()
existing_df = None
try:
    existing_df = pd.read_csv(csv_path)
    existing_dates = set(existing_df['date'])
    print(f"Loaded existing CSV with {len(existing_dates)} records")
except FileNotFoundError:
    print("No existing CSV found, starting fresh")
    existing_df = pd.DataFrame(columns=['id', 'date', 'source_url', 'text'])
except Exception as e:
    print(f"Error reading existing CSV: {e}")
    existing_df = pd.DataFrame(columns=['id', 'date', 'source_url', 'text'])

# Set up requests session with retry logic
session = requests.Session()
session.headers.update({'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36'})
retries = Retry(total=3, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
session.mount('https://', HTTPAdapter(max_retries=retries))

# Function to clean text and preserve sentence structure
def clean_text(text):
    if not text:
        return ""

    # Remove common boilerplate patterns but preserve paragraph structure
    boilerplate_patterns = [
        r'Home \| FOMC.*?(?=\n|$)',
        r'Accessibility.*?(?=\n|$)',
        r'To comment on this site.*?(?=\n|$)',
        r'Last update:.*?(?=\n|$)',
        r'Return to top.*?(?=\n|$)',
        r'Back to Top.*?(?=\n|$)',
        r'PDF.*?FOMC.*?Minutes.*?(?=\n|$)',
        r'Federal Reserve System.*?Board of Governors.*?(?=\n|$)',
        r'Skip to main content.*?(?=\n|$)',
        r'Print\s*Email\s*Share.*?(?=\n|$)',
    ]

    for pattern in boilerplate_patterns:
        text = re.sub(pattern, '', text, flags=re.IGNORECASE)

    # Preserve sentence structure by maintaining proper spacing
    # Replace multiple newlines with double newline (paragraph break)
    text = re.sub(r'\n\s*\n+', '\n\n', text)

    # Ensure sentences are properly spaced (but don't add extra spaces between words)
    text = re.sub(r'([.!?])\s*([A-Z])', r'\1 \2', text)

    # Clean up excessive spaces while preserving single spaces
    text = re.sub(r'[ \t]+', ' ', text)

    # Remove leading/trailing whitespace from each line but preserve line breaks
    lines = [line.strip() for line in text.split('\n')]
    text = '\n'.join(line for line in lines if line)

    return text.strip()

# Robust CSV saving function
def save_data_robust(data, csv_path, existing_df=None):
    """Save data to CSV with better handling of large text fields"""
    if not data:
        return existing_df

    try:
        # Convert to DataFrame
        new_df = pd.DataFrame(data)

        # Handle text length - warn about very long entries
        for idx, row in new_df.iterrows():
            text_len = len(str(row['text'])) if pd.notna(row['text']) else 0
            if text_len > 50000:
                print(f"Processing large text for {row['date']}: {text_len} characters")

        # Combine with existing data
        if existing_df is not None and len(existing_df) > 0:
            combined_df = pd.concat([existing_df, new_df], ignore_index=True)
        else:
            combined_df = new_df

        # Save with better CSV handling
        combined_df.to_csv(csv_path, index=False, quoting=csv.QUOTE_ALL, escapechar='\\')
        print(f"Successfully saved {len(new_df)} new records to {csv_path} (total: {len(combined_df)})")

        return combined_df

    except Exception as e:
        print(f"Error saving to CSV with pandas: {e}")
        print("Attempting fallback CSV save method...")

        # Fallback: save using pure CSV writer
        try:
            with open(csv_path, 'w', newline='', encoding='utf-8') as f:
                writer = csv.writer(f, quoting=csv.QUOTE_ALL)
                writer.writerow(['id', 'date', 'source_url', 'text'])

                if existing_df is not None and len(existing_df) > 0:
                    for _, row in existing_df.iterrows():
                        writer.writerow([row['id'], row['date'], row['source_url'], row['text']])

                for item in data:
                    writer.writerow([item['id'], item['date'], item['source_url'], item['text']])

            print(f"Fallback save successful: {len(data)} new records")
            # Read back to return as DataFrame
            return pd.read_csv(csv_path)
        except Exception as e2:
            print(f"Fallback save also failed: {e2}")
            return existing_df

# Enhanced function to extract main content
def extract_main_content(soup):
    """
    Extract main content from BeautifulSoup object using multiple strategies
    Returns text or None if extraction fails
    """

    # Strategy 1: Try specific content containers (most reliable)
    content_selectors = [
        ('div', {'id': 'article'}),
        ('div', {'class': 'col-xs-12 col-sm-8 col-md-8'}),
        ('div', {'class': 'panel panel-default'}),
        ('div', {'class': 'row'}),
        ('article', {}),
        ('main', {}),
    ]

    for tag, attrs in content_selectors:
        content = soup.find(tag, attrs)
        if content:
            # Remove navigation, footer, and other non-content elements
            for element in content.find_all(['nav', 'header', 'footer', 'script', 'style']):
                element.decompose()

            text = content.get_text(separator=' ', strip=False)
            if len(text) > 500:  # Meaningful content threshold
                return text

    # Strategy 2: Find the largest text block (for cases where structure varies)
    all_divs = soup.find_all(['div', 'article', 'section'])
    max_text = ""
    max_length = 0

    for div in all_divs:
        # Skip navigation and footer areas
        div_class = ' '.join(div.get('class', [])).lower()
        div_id = div.get('id', '').lower()

        if any(skip in div_class + div_id for skip in ['nav', 'header', 'footer', 'sidebar', 'menu']):
            continue

        # Remove scripts and styles
        for element in div.find_all(['script', 'style', 'nav', 'header', 'footer']):
            element.decompose()

        text = div.get_text(separator=' ', strip=False)
        if len(text) > max_length:
            max_length = len(text)
            max_text = text

    if max_length > 500:
        return max_text

    # Strategy 3: Get all paragraphs (fallback)
    paragraphs = soup.find_all('p')
    if len(paragraphs) > 5:  # If there are enough paragraphs
        text = ' '.join([p.get_text(separator=' ', strip=False) for p in paragraphs])
        if len(text) > 500:
            return text

    return None

# Function to scrape minutes for a given date
def scrape_minutes(date):
    date_obj = datetime.strptime(date, '%Y-%m-%d')
    year = date_obj.year
    date_str = date_obj.strftime('%Y%m%d')

    # Define URL formats
    url_old = f'https://www.federalreserve.gov/fomc/minutes/{date_str}.htm'
    url_new = f'https://www.federalreserve.gov/monetarypolicy/fomcminutes{date_str}.htm'
    url_alt = f'https://www.federalreserve.gov/monetarypolicy/fomc{date_str}.htm'

    # For 2000-2003, use url_old; for 2004-2007, try both url_old and url_new;
    # for 2008, try url_alt then url_new; for >2008, use url_new
    if year < 2004:
        urls_to_try = [url_old]
    elif year <= 2007:
        urls_to_try = [url_old, url_new]
    elif year == 2008:
        urls_to_try = [url_alt, url_new, url_old]
    else:
        urls_to_try = [url_new]

    for url in urls_to_try:
        try:
            response = session.get(url, timeout=10)
            response.raise_for_status()

            soup = BeautifulSoup(response.text, 'html5lib')  # Use html5lib for better parsing

            # Extract main content using enhanced function
            text = extract_main_content(soup)

            if text:
                # Clean the text while preserving structure
                text = clean_text(text)

                if len(text) > 500:  # Reasonable minimum for FOMC minutes
                    print(f"✓ Success: Scraped {len(text)} characters for {date} from {url}")
                    return {
                        'id': f"minutes_{date.replace('-', '')}",
                        'date': date,
                        'source_url': url,
                        'text': text
                    }
                else:
                    print(f"⚠ Warning: Text too short ({len(text)} chars) for {date} at {url}")
            else:
                print(f"⚠ No content extracted for {date} at {url}")

        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 404:
                print(f"✗ 404 Not Found: {url}")
            else:
                print(f"✗ HTTP Error {e.response.status_code}: {url}")
        except requests.exceptions.RequestException as e:
            print(f"✗ Request error for {date} at {url}: {e}")
        except Exception as e:
            print(f"✗ General error for {date} at {url}: {e}")

    print(f"✗ Failed to scrape minutes for {date} (tried {len(urls_to_try)} URLs)")
    return None

# Scrape and save data
data = []
successful_scrapes = 0
failed_scrapes = 0
scrape_sizes = []  # Track sizes for reporting

print(f"\nStarting scrape of {len(fomc_dates)} FOMC meeting dates...")
print(f"{'=' * 60}\n")

for idx, date in enumerate(fomc_dates, 1):
    print(f"[{idx}/{len(fomc_dates)}] Processing {date}...")

    if date in existing_dates:
        print(f"→ Skipping {date}: already in CSV\n")
        continue

    result = scrape_minutes(date)
    if result:
        data.append(result)
        successful_scrapes += 1
        scrape_sizes.append({'date': date, 'size': len(result['text'])})
    else:
        failed_scrapes += 1

    print()  # Blank line for readability

    # Save incrementally every 10 dates or at the end
    if len(data) >= 10 or (date == fomc_dates[-1] and data):
        existing_df = save_data_robust(data, csv_path, existing_df)
        data = []  # Clear data after saving

    time.sleep(1)  # Avoid overwhelming the server

# Print summary
print(f"\n{'=' * 60}")
print(f"SCRAPING COMPLETE")
print(f"{'=' * 60}")
print(f"✓ Successful: {successful_scrapes}")
print(f"✗ Failed: {failed_scrapes}")
print(f"Total processed: {successful_scrapes + failed_scrapes}")

if os.path.exists(csv_path):
    try:
        final_df = pd.read_csv(csv_path)
        print(f"\nFinal CSV contains {len(final_df)} records")
        print(f"File size: {os.path.getsize(csv_path) / (1024 * 1024):.2f} MB")

        # Show the 10 shortest scrapes
        if scrape_sizes:
            print(f"\n{'=' * 60}")
            print(f"10 SHORTEST SCRAPES FROM THIS SESSION")
            print(f"{'=' * 60}")
            sorted_sizes = sorted(scrape_sizes, key=lambda x: x['size'])[:10]
            for i, item in enumerate(sorted_sizes, 1):
                print(f"{i:2}. {item['date']}: {item['size']:,} characters")

        # Show any remaining missing dates
        scraped_dates = set(final_df['date'])
        missing_dates = [d for d in fomc_dates if d not in scraped_dates]
        if missing_dates:
            print(f"\n⚠ Still missing {len(missing_dates)} dates:")
            for d in missing_dates[:10]:  # Show first 10
                print(f"  - {d}")
            if len(missing_dates) > 10:
                print(f"  ... and {len(missing_dates) - 10} more")
    except Exception as e:
        print(f"Error reading final CSV: {e}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing all available years
# No existing CSV found, starting fresh
#
# Starting scrape of 199 FOMC meeting dates...
# ============================================================
#
# [1/199] Processing 2000-02-02...
# ✓ Success: Scraped 42297 characters for 2000-02-02 from https://www.federalreserve.gov/fomc/minutes/20000202.htm
#
# [2/199] Processing 2000-03-21...
# ✓ Success: Scraped 28608 characters for 2000-03-21 from https://www.federalreserve.gov/fomc/minutes/20000321.htm
#
# [3/199] Processing 2000-05-16...
# ✓ Success: Scraped 25577 characters for 2000-05-16 from https://www.federalreserve.gov/fomc/minutes/20000516.htm
#
# [4/199] Processing 2000-06-28...
# ✓ Success: Scraped 27408 characters for 2000-06-28 from https://www.federalreserve.gov/fomc/minutes/20000628.htm
#
# [5/199] Processing 2000-08-22...
# ✓ Success: Scraped 26877 characters for 2000-08-22 from https://www.federalreserve.gov/fomc/minutes/20000822.htm
#
# [6/199] Processing 2000-10-03...
# ✓ Success: Scraped 24032 characters for 2000-10-03 from https://www.federalreserve.gov/fomc/minutes/20001003.htm
#
# [7/199] Processing 2000-11-15...
# ✓ Success: Scraped 27777 characters for 2000-11-15 from https://www.federalreserve.gov/fomc/minutes/20001115.htm
#
# [8/199] Processing 2000-12-19...
# ✓ Success: Scraped 32174 characters for 2000-12-19 from https://www.federalreserve.gov/fomc/minutes/20001219.htm
#
# [9/199] Processing 2001-01-31...
# ✓ Success: Scraped 45693 characters for 2001-01-31 from https://www.federalreserve.gov/fomc/minutes/20010131.htm
#
# [10/199] Processing 2001-03-20...
# ✓ Success: Scraped 30546 characters for 2001-03-20 from https://www.federalreserve.gov/fomc/minutes/20010320.htm
#
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 10)
# [11/199] Processing 2001-05-15...
# ✓ Success: Scraped 31683 characters for 2001-05-15 from https://www.federalreserve.gov/fomc/minutes/20010515.htm
#
# [12/199] Processing 2001-06-27...
# ✓ Success: Scraped 31767 characters for 2001-06-27 from https://www.federalreserve.gov/fomc/minutes/20010627.htm
#
# [13/199] Processing 2001-08-21...
# ✓ Success: Scraped 30545 characters for 2001-08-21 from https://www.federalreserve.gov/fomc/minutes/20010821.htm
#
# [14/199] Processing 2001-10-02...
# ✓ Success: Scraped 28433 characters for 2001-10-02 from https://www.federalreserve.gov/fomc/minutes/20011002.htm
#
# [15/199] Processing 2001-11-06...
# ✓ Success: Scraped 27550 characters for 2001-11-06 from https://www.federalreserve.gov/fomc/minutes/20011106.htm
#
# [16/199] Processing 2001-12-11...
# ✓ Success: Scraped 29194 characters for 2001-12-11 from https://www.federalreserve.gov/fomc/minutes/20011211.htm
#
# [17/199] Processing 2002-01-30...
# ✓ Success: Scraped 38393 characters for 2002-01-30 from https://www.federalreserve.gov/fomc/minutes/20020130.htm
#
# [18/199] Processing 2002-03-19...
# ✓ Success: Scraped 29640 characters for 2002-03-19 from https://www.federalreserve.gov/fomc/minutes/20020319.htm
#
# [19/199] Processing 2002-05-07...
# ✓ Success: Scraped 25096 characters for 2002-05-07 from https://www.federalreserve.gov/fomc/minutes/20020507.htm
#
# [20/199] Processing 2002-06-26...
# ✓ Success: Scraped 27322 characters for 2002-06-26 from https://www.federalreserve.gov/fomc/minutes/20020626.htm
#
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 20)
# [21/199] Processing 2002-08-13...
# ✓ Success: Scraped 26511 characters for 2002-08-13 from https://www.federalreserve.gov/fomc/minutes/20020813.htm
#
# [22/199] Processing 2002-09-24...
# ✓ Success: Scraped 25039 characters for 2002-09-24 from https://www.federalreserve.gov/fomc/minutes/20020924.htm
#
# [23/199] Processing 2002-11-06...
# ✓ Success: Scraped 29940 characters for 2002-11-06 from https://www.federalreserve.gov/fomc/minutes/20021106.htm
#
# [24/199] Processing 2002-12-10...
# ✓ Success: Scraped 21718 characters for 2002-12-10 from https://www.federalreserve.gov/fomc/minutes/20021210.htm
#
# [25/199] Processing 2003-01-29...
# ✓ Success: Scraped 36115 characters for 2003-01-29 from https://www.federalreserve.gov/fomc/minutes/20030129.htm
#
# [26/199] Processing 2003-03-18...
# ✓ Success: Scraped 23669 characters for 2003-03-18 from https://www.federalreserve.gov/fomc/minutes/20030318.htm
#
# [27/199] Processing 2003-05-06...
# ✓ Success: Scraped 25402 characters for 2003-05-06 from https://www.federalreserve.gov/fomc/minutes/20030506.htm
#
# [28/199] Processing 2003-06-25...
# ✓ Success: Scraped 32145 characters for 2003-06-25 from https://www.federalreserve.gov/fomc/minutes/20030625.htm
#
# [29/199] Processing 2003-08-12...
# ✓ Success: Scraped 24919 characters for 2003-08-12 from https://www.federalreserve.gov/fomc/minutes/20030812.htm
#
# [30/199] Processing 2003-09-16...
# ✓ Success: Scraped 25732 characters for 2003-09-16 from https://www.federalreserve.gov/fomc/minutes/20030916.htm
#
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 30)
# [31/199] Processing 2003-10-28...
# ✓ Success: Scraped 24473 characters for 2003-10-28 from https://www.federalreserve.gov/fomc/minutes/20031028.htm
#
# [32/199] Processing 2003-12-09...
# ✓ Success: Scraped 27721 characters for 2003-12-09 from https://www.federalreserve.gov/fomc/minutes/20031209.htm
#
# [33/199] Processing 2004-01-28...
# ✓ Success: Scraped 54349 characters for 2004-01-28 from https://www.federalreserve.gov/fomc/minutes/20040128.htm
#
# [34/199] Processing 2004-03-16...
# ✓ Success: Scraped 25034 characters for 2004-03-16 from https://www.federalreserve.gov/fomc/minutes/20040316.htm
#
# [35/199] Processing 2004-05-04...
# ✓ Success: Scraped 29597 characters for 2004-05-04 from https://www.federalreserve.gov/fomc/minutes/20040504.htm
#
# [36/199] Processing 2004-06-30...
# ✓ Success: Scraped 29195 characters for 2004-06-30 from https://www.federalreserve.gov/fomc/minutes/20040630.htm
#
# [37/199] Processing 2004-08-10...
# ✓ Success: Scraped 24631 characters for 2004-08-10 from https://www.federalreserve.gov/fomc/minutes/20040810.htm
#
# [38/199] Processing 2004-09-21...
# ✓ Success: Scraped 25874 characters for 2004-09-21 from https://www.federalreserve.gov/fomc/minutes/20040921.htm
#
# [39/199] Processing 2004-11-10...
# ✓ Success: Scraped 22926 characters for 2004-11-10 from https://www.federalreserve.gov/fomc/minutes/20041110.htm
#
# [40/199] Processing 2004-12-14...
# ✓ Success: Scraped 25559 characters for 2004-12-14 from https://www.federalreserve.gov/fomc/minutes/20041214.htm
#
# Processing large text for 2004-01-28: 54349 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 40)
# [41/199] Processing 2005-02-02...
# ✓ Success: Scraped 44001 characters for 2005-02-02 from https://www.federalreserve.gov/fomc/minutes/20050202.htm
#
# [42/199] Processing 2005-03-22...
# ✓ Success: Scraped 26895 characters for 2005-03-22 from https://www.federalreserve.gov/fomc/minutes/20050322.htm
#
# [43/199] Processing 2005-05-03...
# ✓ Success: Scraped 26210 characters for 2005-05-03 from https://www.federalreserve.gov/fomc/minutes/20050503.htm
#
# [44/199] Processing 2005-06-30...
# ✓ Success: Scraped 27253 characters for 2005-06-30 from https://www.federalreserve.gov/fomc/minutes/20050630.htm
#
# [45/199] Processing 2005-08-09...
# ✓ Success: Scraped 20271 characters for 2005-08-09 from https://www.federalreserve.gov/fomc/minutes/20050809.htm
#
# [46/199] Processing 2005-09-20...
# ✓ Success: Scraped 21652 characters for 2005-09-20 from https://www.federalreserve.gov/fomc/minutes/20050920.htm
#
# [47/199] Processing 2005-11-01...
# ✓ Success: Scraped 23048 characters for 2005-11-01 from https://www.federalreserve.gov/fomc/minutes/20051101.htm
#
# [48/199] Processing 2005-12-13...
# ✓ Success: Scraped 22478 characters for 2005-12-13 from https://www.federalreserve.gov/fomc/minutes/20051213.htm
#
# [49/199] Processing 2006-01-31...
# ✓ Success: Scraped 40549 characters for 2006-01-31 from https://www.federalreserve.gov/fomc/minutes/20060131.htm
#
# [50/199] Processing 2006-03-28...
# ✓ Success: Scraped 25600 characters for 2006-03-28 from https://www.federalreserve.gov/fomc/minutes/20060328.htm
#
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 50)
# [51/199] Processing 2006-05-10...
# ✓ Success: Scraped 26915 characters for 2006-05-10 from https://www.federalreserve.gov/fomc/minutes/20060510.htm
#
# [52/199] Processing 2006-06-29...
# ✓ Success: Scraped 25537 characters for 2006-06-29 from https://www.federalreserve.gov/fomc/minutes/20060629.htm
#
# [53/199] Processing 2006-08-08...
# ✓ Success: Scraped 23335 characters for 2006-08-08 from https://www.federalreserve.gov/fomc/minutes/20060808.htm
#
# [54/199] Processing 2006-09-20...
# ✓ Success: Scraped 23431 characters for 2006-09-20 from https://www.federalreserve.gov/fomc/minutes/20060920.htm
#
# [55/199] Processing 2006-10-25...
# ✓ Success: Scraped 28062 characters for 2006-10-25 from https://www.federalreserve.gov/fomc/minutes/20061025.htm
#
# [56/199] Processing 2006-12-12...
# ✓ Success: Scraped 25611 characters for 2006-12-12 from https://www.federalreserve.gov/fomc/minutes/20061212.htm
#
# [57/199] Processing 2007-01-31...
# ✓ Success: Scraped 43024 characters for 2007-01-31 from https://www.federalreserve.gov/fomc/minutes/20070131.htm
#
# [58/199] Processing 2007-03-21...
# ✓ Success: Scraped 26338 characters for 2007-03-21 from https://www.federalreserve.gov/fomc/minutes/20070321.htm
#
# [59/199] Processing 2007-05-09...
# ✓ Success: Scraped 26769 characters for 2007-05-09 from https://www.federalreserve.gov/fomc/minutes/20070509.htm
#
# [60/199] Processing 2007-06-28...
# ✓ Success: Scraped 28729 characters for 2007-06-28 from https://www.federalreserve.gov/fomc/minutes/20070628.htm
#
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 60)
# [61/199] Processing 2007-08-07...
# ✓ Success: Scraped 28747 characters for 2007-08-07 from https://www.federalreserve.gov/fomc/minutes/20070807.htm
#
# [62/199] Processing 2007-09-18...
# ✓ Success: Scraped 36711 characters for 2007-09-18 from https://www.federalreserve.gov/fomc/minutes/20070918.htm
#
# [63/199] Processing 2007-10-31...
# ✗ 404 Not Found: https://www.federalreserve.gov/fomc/minutes/20071031.htm
# ✓ Success: Scraped 36581 characters for 2007-10-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20071031.htm
#
# [64/199] Processing 2007-12-11...
# ✗ 404 Not Found: https://www.federalreserve.gov/fomc/minutes/20071211.htm
# ✓ Success: Scraped 39932 characters for 2007-12-11 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20071211.htm
#
# [65/199] Processing 2008-01-30...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20080130.htm
# ✓ Success: Scraped 63377 characters for 2008-01-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20080130.htm
#
# [66/199] Processing 2008-03-18...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20080318.htm
# ✓ Success: Scraped 40378 characters for 2008-03-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20080318.htm
#
# [67/199] Processing 2008-04-30...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20080430.htm
# ✓ Success: Scraped 46394 characters for 2008-04-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20080430.htm
#
# [68/199] Processing 2008-06-25...
# ✓ Success: Scraped 39397 characters for 2008-06-25 from https://www.federalreserve.gov/monetarypolicy/fomc20080625.htm
#
# [69/199] Processing 2008-08-05...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20080805.htm
# ✓ Success: Scraped 34446 characters for 2008-08-05 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20080805.htm
#
# [70/199] Processing 2008-09-16...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20080916.htm
# ✓ Success: Scraped 30555 characters for 2008-09-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20080916.htm
#
# Processing large text for 2008-01-30: 63377 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 70)
# [71/199] Processing 2008-10-29...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20081029.htm
# ✓ Success: Scraped 53161 characters for 2008-10-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20081029.htm
#
# [72/199] Processing 2008-12-16...
# ✗ 404 Not Found: https://www.federalreserve.gov/monetarypolicy/fomc20081216.htm
# ✓ Success: Scraped 50694 characters for 2008-12-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20081216.htm
#
# [73/199] Processing 2009-01-28...
# ✓ Success: Scraped 71796 characters for 2009-01-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090128.htm
#
# [74/199] Processing 2009-03-18...
# ✓ Success: Scraped 46088 characters for 2009-03-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090318.htm
#
# [75/199] Processing 2009-04-29...
# ✓ Success: Scraped 43470 characters for 2009-04-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090429.htm
#
# [76/199] Processing 2009-06-24...
# ✓ Success: Scraped 54325 characters for 2009-06-24 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090624.htm
#
# [77/199] Processing 2009-08-12...
# ✓ Success: Scraped 45653 characters for 2009-08-12 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090812.htm
#
# [78/199] Processing 2009-09-23...
# ✓ Success: Scraped 49326 characters for 2009-09-23 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20090923.htm
#
# [79/199] Processing 2009-11-04...
# ✓ Success: Scraped 46132 characters for 2009-11-04 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20091104.htm
#
# [80/199] Processing 2009-12-16...
# ✓ Success: Scraped 53093 characters for 2009-12-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20091216.htm
#
# Processing large text for 2008-10-29: 53161 characters
# Processing large text for 2008-12-16: 50694 characters
# Processing large text for 2009-01-28: 71796 characters
# Processing large text for 2009-06-24: 54325 characters
# Processing large text for 2009-12-16: 53093 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 80)
# [81/199] Processing 2010-01-27...
# ✓ Success: Scraped 74235 characters for 2010-01-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100127.htm
#
# [82/199] Processing 2010-03-16...
# ✓ Success: Scraped 43819 characters for 2010-03-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100316.htm
#
# [83/199] Processing 2010-04-28...
# ✓ Success: Scraped 46545 characters for 2010-04-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100428.htm
#
# [84/199] Processing 2010-06-23...
# ✓ Success: Scraped 52338 characters for 2010-06-23 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100623.htm
#
# [85/199] Processing 2010-08-10...
# ✓ Success: Scraped 44146 characters for 2010-08-10 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100810.htm
#
# [86/199] Processing 2010-09-21...
# ✓ Success: Scraped 40121 characters for 2010-09-21 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20100921.htm
#
# [87/199] Processing 2010-11-03...
# ✓ Success: Scraped 47612 characters for 2010-11-03 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20101103.htm
#
# [88/199] Processing 2010-12-14...
# ✓ Success: Scraped 44519 characters for 2010-12-14 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20101214.htm
#
# [89/199] Processing 2011-01-26...
# ✓ Success: Scraped 69273 characters for 2011-01-26 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110126.htm
#
# [90/199] Processing 2011-03-15...
# ✓ Success: Scraped 44837 characters for 2011-03-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110315.htm
#
# Processing large text for 2010-01-27: 74235 characters
# Processing large text for 2010-06-23: 52338 characters
# Processing large text for 2011-01-26: 69273 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 90)
# [91/199] Processing 2011-04-27...
# ✓ Success: Scraped 51038 characters for 2011-04-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110427.htm
#
# [92/199] Processing 2011-06-22...
# ✓ Success: Scraped 49241 characters for 2011-06-22 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110622.htm
#
# [93/199] Processing 2011-08-09...
# ✓ Success: Scraped 43796 characters for 2011-08-09 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110809.htm
#
# [94/199] Processing 2011-09-21...
# ✓ Success: Scraped 55825 characters for 2011-09-21 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20110921.htm
#
# [95/199] Processing 2011-11-02...
# ✓ Success: Scraped 50925 characters for 2011-11-02 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20111102.htm
#
# [96/199] Processing 2011-12-13...
# ✓ Success: Scraped 51034 characters for 2011-12-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20111213.htm
#
# [97/199] Processing 2012-01-25...
# ✓ Success: Scraped 71699 characters for 2012-01-25 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120125.htm
#
# [98/199] Processing 2012-03-13...
# ✓ Success: Scraped 42062 characters for 2012-03-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120313.htm
#
# [99/199] Processing 2012-04-25...
# ✓ Success: Scraped 46622 characters for 2012-04-25 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120425.htm
#
# [100/199] Processing 2012-06-20...
# ✓ Success: Scraped 52723 characters for 2012-06-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120620.htm
#
# Processing large text for 2011-04-27: 51038 characters
# Processing large text for 2011-09-21: 55825 characters
# Processing large text for 2011-11-02: 50925 characters
# Processing large text for 2011-12-13: 51034 characters
# Processing large text for 2012-01-25: 71699 characters
# Processing large text for 2012-06-20: 52723 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 100)
# [101/199] Processing 2012-08-01...
# ✓ Success: Scraped 47256 characters for 2012-08-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120801.htm
#
# [102/199] Processing 2012-09-13...
# ✓ Success: Scraped 50162 characters for 2012-09-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20120913.htm
#
# [103/199] Processing 2012-12-12...
# ✓ Success: Scraped 50575 characters for 2012-12-12 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20121212.htm
#
# [104/199] Processing 2013-03-20...
# ✓ Success: Scraped 47913 characters for 2013-03-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20130320.htm
#
# [105/199] Processing 2013-05-01...
# ✓ Success: Scraped 45273 characters for 2013-05-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20130501.htm
#
# [106/199] Processing 2013-06-19...
# ✓ Success: Scraped 53774 characters for 2013-06-19 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20130619.htm
#
# [107/199] Processing 2013-07-31...
# ✓ Success: Scraped 47221 characters for 2013-07-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20130731.htm
#
# [108/199] Processing 2013-09-18...
# ✓ Success: Scraped 54143 characters for 2013-09-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20130918.htm
#
# [109/199] Processing 2013-10-30...
# ✓ Success: Scraped 50574 characters for 2013-10-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20131030.htm
#
# [110/199] Processing 2013-12-18...
# ✓ Success: Scraped 58179 characters for 2013-12-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20131218.htm
#
# Processing large text for 2012-09-13: 50162 characters
# Processing large text for 2012-12-12: 50575 characters
# Processing large text for 2013-06-19: 53774 characters
# Processing large text for 2013-09-18: 54143 characters
# Processing large text for 2013-10-30: 50574 characters
# Processing large text for 2013-12-18: 58179 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 110)
# [111/199] Processing 2014-01-29...
# ✓ Success: Scraped 79183 characters for 2014-01-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140129.htm
#
# [112/199] Processing 2014-03-19...
# ✓ Success: Scraped 55157 characters for 2014-03-19 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140319.htm
#
# [113/199] Processing 2014-04-30...
# ✓ Success: Scraped 44645 characters for 2014-04-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140430.htm
#
# [114/199] Processing 2014-06-18...
# ✓ Success: Scraped 56423 characters for 2014-06-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140618.htm
#
# [115/199] Processing 2014-07-30...
# ✓ Success: Scraped 52759 characters for 2014-07-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140730.htm
#
# [116/199] Processing 2014-09-17...
# ✓ Success: Scraped 60300 characters for 2014-09-17 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20140917.htm
#
# [117/199] Processing 2014-10-29...
# ✓ Success: Scraped 55100 characters for 2014-10-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20141029.htm
#
# [118/199] Processing 2014-12-17...
# ✓ Success: Scraped 49884 characters for 2014-12-17 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20141217.htm
#
# [119/199] Processing 2015-01-28...
# ✓ Success: Scraped 94849 characters for 2015-01-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150128.htm
#
# [120/199] Processing 2015-03-18...
# ✓ Success: Scraped 55675 characters for 2015-03-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150318.htm
#
# Processing large text for 2014-01-29: 79183 characters
# Processing large text for 2014-03-19: 55157 characters
# Processing large text for 2014-06-18: 56423 characters
# Processing large text for 2014-07-30: 52759 characters
# Processing large text for 2014-09-17: 60300 characters
# Processing large text for 2014-10-29: 55100 characters
# Processing large text for 2015-01-28: 94849 characters
# Processing large text for 2015-03-18: 55675 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 120)
# [121/199] Processing 2015-04-29...
# ✓ Success: Scraped 50371 characters for 2015-04-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150429.htm
#
# [122/199] Processing 2015-06-17...
# ✓ Success: Scraped 53225 characters for 2015-06-17 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150617.htm
#
# [123/199] Processing 2015-07-29...
# ✓ Success: Scraped 55964 characters for 2015-07-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150729.htm
#
# [124/199] Processing 2015-09-17...
# ✓ Success: Scraped 49475 characters for 2015-09-17 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20150917.htm
#
# [125/199] Processing 2015-10-28...
# ✓ Success: Scraped 53702 characters for 2015-10-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20151028.htm
#
# [126/199] Processing 2015-12-16...
# ✓ Success: Scraped 50765 characters for 2015-12-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20151216.htm
#
# [127/199] Processing 2016-01-27...
# ✓ Success: Scraped 90465 characters for 2016-01-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160127.htm
#
# [128/199] Processing 2016-03-16...
# ✓ Success: Scraped 51313 characters for 2016-03-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160316.htm
#
# [129/199] Processing 2016-04-27...
# ✓ Success: Scraped 61613 characters for 2016-04-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160427.htm
#
# [130/199] Processing 2016-06-15...
# ✓ Success: Scraped 54549 characters for 2016-06-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160615.htm
#
# Processing large text for 2015-04-29: 50371 characters
# Processing large text for 2015-06-17: 53225 characters
# Processing large text for 2015-07-29: 55964 characters
# Processing large text for 2015-10-28: 53702 characters
# Processing large text for 2015-12-16: 50765 characters
# Processing large text for 2016-01-27: 90465 characters
# Processing large text for 2016-03-16: 51313 characters
# Processing large text for 2016-04-27: 61613 characters
# Processing large text for 2016-06-15: 54549 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 130)
# [131/199] Processing 2016-07-27...
# ✓ Success: Scraped 67949 characters for 2016-07-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160727.htm
#
# [132/199] Processing 2016-09-21...
# ✓ Success: Scraped 71574 characters for 2016-09-21 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20160921.htm
#
# [133/199] Processing 2016-11-02...
# ✓ Success: Scraped 61285 characters for 2016-11-02 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20161102.htm
#
# [134/199] Processing 2016-12-14...
# ✓ Success: Scraped 55557 characters for 2016-12-14 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20161214.htm
#
# [135/199] Processing 2017-02-01...
# ✓ Success: Scraped 83064 characters for 2017-02-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170201.htm
#
# [136/199] Processing 2017-03-15...
# ✓ Success: Scraped 59559 characters for 2017-03-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170315.htm
#
# [137/199] Processing 2017-05-03...
# ✓ Success: Scraped 56642 characters for 2017-05-03 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170503.htm
#
# [138/199] Processing 2017-06-14...
# ✓ Success: Scraped 58332 characters for 2017-06-14 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170614.htm
#
# [139/199] Processing 2017-07-26...
# ✓ Success: Scraped 49711 characters for 2017-07-26 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170726.htm
#
# [140/199] Processing 2017-09-20...
# ✓ Success: Scraped 57156 characters for 2017-09-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20170920.htm
#
# Processing large text for 2016-07-27: 67949 characters
# Processing large text for 2016-09-21: 71574 characters
# Processing large text for 2016-11-02: 61285 characters
# Processing large text for 2016-12-14: 55557 characters
# Processing large text for 2017-02-01: 83064 characters
# Processing large text for 2017-03-15: 59559 characters
# Processing large text for 2017-05-03: 56642 characters
# Processing large text for 2017-06-14: 58332 characters
# Processing large text for 2017-09-20: 57156 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 140)
# [141/199] Processing 2017-11-01...
# ✓ Success: Scraped 50680 characters for 2017-11-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20171101.htm
#
# [142/199] Processing 2017-12-13...
# ✓ Success: Scraped 49337 characters for 2017-12-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20171213.htm
#
# [143/199] Processing 2018-01-31...
# ✓ Success: Scraped 81424 characters for 2018-01-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180131.htm
#
# [144/199] Processing 2018-03-21...
# ✓ Success: Scraped 48471 characters for 2018-03-21 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180321.htm
#
# [145/199] Processing 2018-05-02...
# ✓ Success: Scraped 52553 characters for 2018-05-02 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180502.htm
#
# [146/199] Processing 2018-06-13...
# ✓ Success: Scraped 47391 characters for 2018-06-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180613.htm
#
# [147/199] Processing 2018-08-01...
# ✓ Success: Scraped 55281 characters for 2018-08-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180801.htm
#
# [148/199] Processing 2018-09-26...
# ✓ Success: Scraped 47439 characters for 2018-09-26 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
#
# [149/199] Processing 2018-11-08...
# ✓ Success: Scraped 55522 characters for 2018-11-08 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20181108.htm
#
# [150/199] Processing 2018-12-19...
# ✓ Success: Scraped 56482 characters for 2018-12-19 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20181219.htm
#
# Processing large text for 2017-11-01: 50680 characters
# Processing large text for 2018-01-31: 81424 characters
# Processing large text for 2018-05-02: 52553 characters
# Processing large text for 2018-08-01: 55281 characters
# Processing large text for 2018-11-08: 55522 characters
# Processing large text for 2018-12-19: 56482 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 150)
# [151/199] Processing 2019-01-30...
# ✓ Success: Scraped 94386 characters for 2019-01-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190130.htm
#
# [152/199] Processing 2019-03-20...
# ✓ Success: Scraped 64130 characters for 2019-03-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190320.htm
#
# [153/199] Processing 2019-05-01...
# ✓ Success: Scraped 62096 characters for 2019-05-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190501.htm
#
# [154/199] Processing 2019-06-19...
# ✓ Success: Scraped 55176 characters for 2019-06-19 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190619.htm
#
# [155/199] Processing 2019-07-31...
# ✓ Success: Scraped 71411 characters for 2019-07-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190731.htm
#
# [156/199] Processing 2019-09-18...
# ✓ Success: Scraped 71206 characters for 2019-09-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20190918.htm
#
# [157/199] Processing 2019-10-30...
# ✓ Success: Scraped 83935 characters for 2019-10-30 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20191030.htm
#
# [158/199] Processing 2019-12-11...
# ✓ Success: Scraped 57132 characters for 2019-12-11 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20191211.htm
#
# [159/199] Processing 2020-01-29...
# ✓ Success: Scraped 88129 characters for 2020-01-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200129.htm
#
# [160/199] Processing 2020-03-15...
# ✓ Success: Scraped 66019 characters for 2020-03-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200315.htm
#
# Processing large text for 2019-01-30: 94386 characters
# Processing large text for 2019-03-20: 64130 characters
# Processing large text for 2019-05-01: 62096 characters
# Processing large text for 2019-06-19: 55176 characters
# Processing large text for 2019-07-31: 71411 characters
# Processing large text for 2019-09-18: 71206 characters
# Processing large text for 2019-10-30: 83935 characters
# Processing large text for 2019-12-11: 57132 characters
# Processing large text for 2020-01-29: 88129 characters
# Processing large text for 2020-03-15: 66019 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 160)
# [161/199] Processing 2020-04-29...
# ✓ Success: Scraped 63054 characters for 2020-04-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200429.htm
#
# [162/199] Processing 2020-06-10...
# ✓ Success: Scraped 67171 characters for 2020-06-10 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200610.htm
#
# [163/199] Processing 2020-07-29...
# ✓ Success: Scraped 60458 characters for 2020-07-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200729.htm
#
# [164/199] Processing 2020-09-16...
# ✓ Success: Scraped 66107 characters for 2020-09-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20200916.htm
#
# [165/199] Processing 2020-11-05...
# ✓ Success: Scraped 63915 characters for 2020-11-05 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20201105.htm
#
# [166/199] Processing 2020-12-16...
# ✓ Success: Scraped 55767 characters for 2020-12-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20201216.htm
#
# [167/199] Processing 2021-01-27...
# ✓ Success: Scraped 84554 characters for 2021-01-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210127.htm
#
# [168/199] Processing 2021-03-17...
# ✓ Success: Scraped 58303 characters for 2021-03-17 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210317.htm
#
# [169/199] Processing 2021-04-28...
# ✓ Success: Scraped 58954 characters for 2021-04-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210428.htm
#
# [170/199] Processing 2021-06-16...
# ✓ Success: Scraped 63778 characters for 2021-06-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210616.htm
#
# Processing large text for 2020-04-29: 63054 characters
# Processing large text for 2020-06-10: 67171 characters
# Processing large text for 2020-07-29: 60458 characters
# Processing large text for 2020-09-16: 66107 characters
# Processing large text for 2020-11-05: 63915 characters
# Processing large text for 2020-12-16: 55767 characters
# Processing large text for 2021-01-27: 84554 characters
# Processing large text for 2021-03-17: 58303 characters
# Processing large text for 2021-04-28: 58954 characters
# Processing large text for 2021-06-16: 63778 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 170)
# [171/199] Processing 2021-07-28...
# ✓ Success: Scraped 70469 characters for 2021-07-28 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210728.htm
#
# [172/199] Processing 2021-09-22...
# ✓ Success: Scraped 58535 characters for 2021-09-22 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20210922.htm
#
# [173/199] Processing 2021-11-03...
# ✓ Success: Scraped 55565 characters for 2021-11-03 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20211103.htm
#
# [174/199] Processing 2021-12-15...
# ✓ Success: Scraped 62907 characters for 2021-12-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20211215.htm
#
# [175/199] Processing 2022-01-26...
# ✓ Success: Scraped 89911 characters for 2022-01-26 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220126.htm
#
# [176/199] Processing 2022-03-16...
# ✓ Success: Scraped 57365 characters for 2022-03-16 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220316.htm
#
# [177/199] Processing 2022-05-04...
# ✓ Success: Scraped 52023 characters for 2022-05-04 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220504.htm
#
# [178/199] Processing 2022-06-15...
# ✓ Success: Scraped 52651 characters for 2022-06-15 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220615.htm
#
# [179/199] Processing 2022-07-27...
# ✓ Success: Scraped 56629 characters for 2022-07-27 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220727.htm
#
# [180/199] Processing 2022-09-21...
# ✓ Success: Scraped 51767 characters for 2022-09-21 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20220921.htm
#
# Processing large text for 2021-07-28: 70469 characters
# Processing large text for 2021-09-22: 58535 characters
# Processing large text for 2021-11-03: 55565 characters
# Processing large text for 2021-12-15: 62907 characters
# Processing large text for 2022-01-26: 89911 characters
# Processing large text for 2022-03-16: 57365 characters
# Processing large text for 2022-05-04: 52023 characters
# Processing large text for 2022-06-15: 52651 characters
# Processing large text for 2022-07-27: 56629 characters
# Processing large text for 2022-09-21: 51767 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 180)
# [181/199] Processing 2022-11-02...
# ✓ Success: Scraped 53736 characters for 2022-11-02 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20221102.htm
#
# [182/199] Processing 2022-12-14...
# ✓ Success: Scraped 51475 characters for 2022-12-14 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20221214.htm
#
# [183/199] Processing 2023-02-01...
# ✓ Success: Scraped 57893 characters for 2023-02-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230201.htm
#
# [184/199] Processing 2023-03-22...
# ✓ Success: Scraped 49749 characters for 2023-03-22 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230322.htm
#
# [185/199] Processing 2023-05-03...
# ✓ Success: Scraped 54595 characters for 2023-05-03 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230503.htm
#
# [186/199] Processing 2023-06-14...
# ✓ Success: Scraped 47071 characters for 2023-06-14 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230614.htm
#
# [187/199] Processing 2023-07-26...
# ✓ Success: Scraped 45884 characters for 2023-07-26 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230726.htm
#
# [188/199] Processing 2023-09-20...
# ✓ Success: Scraped 43518 characters for 2023-09-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20230920.htm
#
# [189/199] Processing 2023-11-01...
# ✓ Success: Scraped 46094 characters for 2023-11-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20231101.htm
#
# [190/199] Processing 2023-12-13...
# ✓ Success: Scraped 45586 characters for 2023-12-13 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20231213.htm
#
# Processing large text for 2022-11-02: 53736 characters
# Processing large text for 2022-12-14: 51475 characters
# Processing large text for 2023-02-01: 57893 characters
# Processing large text for 2023-05-03: 54595 characters
# Successfully saved 10 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 190)
# [191/199] Processing 2024-01-31...
# ✓ Success: Scraped 49982 characters for 2024-01-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240131.htm
#
# [192/199] Processing 2024-03-20...
# ✓ Success: Scraped 48471 characters for 2024-03-20 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240320.htm
#
# [193/199] Processing 2024-05-01...
# ✓ Success: Scraped 47480 characters for 2024-05-01 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240501.htm
#
# [194/199] Processing 2024-06-12...
# ✓ Success: Scraped 43492 characters for 2024-06-12 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240612.htm
#
# [195/199] Processing 2024-07-31...
# ✓ Success: Scraped 44470 characters for 2024-07-31 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240731.htm
#
# [196/199] Processing 2024-09-18...
# ✓ Success: Scraped 43993 characters for 2024-09-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20240918.htm
#
# [197/199] Processing 2024-11-07...
# ✓ Success: Scraped 48835 characters for 2024-11-07 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20241107.htm
#
# [198/199] Processing 2024-12-18...
# ✓ Success: Scraped 45546 characters for 2024-12-18 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20241218.htm
#
# [199/199] Processing 2025-01-29...
# ✓ Success: Scraped 54533 characters for 2025-01-29 from https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
#
# Processing large text for 2025-01-29: 54533 characters
# Successfully saved 9 new records to /content/drive/MyDrive/Minutes/fomc_minutes.csv (total: 199)
#
# ============================================================
# SCRAPING COMPLETE
# ============================================================
# ✓ Successful: 199
# ✗ Failed: 0
# Total processed: 199
#
# Final CSV contains 199 records
# File size: 8.98 MB
#
# ============================================================
# 10 SHORTEST SCRAPES FROM THIS SESSION
# ============================================================
#  1. 2005-08-09: 20,271 characters
#  2. 2005-09-20: 21,652 characters
#  3. 2002-12-10: 21,718 characters
#  4. 2005-12-13: 22,478 characters
#  5. 2004-11-10: 22,926 characters
#  6. 2005-11-01: 23,048 characters
#  7. 2006-08-08: 23,335 characters
#  8. 2006-09-20: 23,431 characters
#  9. 2003-03-18: 23,669 characters
# 10. 2000-10-03: 24,032 characters

# %%
#@title Additional Clean
import pandas as pd
import re

input_file = '/content/drive/MyDrive/FedComs/Minutes/fomc_minutes.csv'
output_dir = '/content/drive/MyDrive/FedComs/Minutes'

print("Reading FOMC minutes...")
df = pd.read_csv(input_file)
print(f"Loaded {len(df)} minutes")

df['date'] = pd.to_datetime(df['date'])

def fix_text_encoding(text):
    """Fix common text encoding issues from web scraping."""
    text = text.replace('â', '—')
    text = text.replace('â', '—')
    text = text.replace('â', '"')
    text = text.replace('â', '"')
    text = text.replace('\u2013', '–')
    text = text.replace('\u2014', '—')
    text = text.replace('\u2018', "'")
    text = text.replace('\u2019', "'")
    text = text.replace('\u201c', '"')
    text = text.replace('\u201d', '"')
    text = text.replace('\u2026', '...')
    text = re.sub(r'[\x00-\x08\x0b-\x0c\x0e-\x1f\x7f-\x9f]', '', text)
    return text

def is_in_footnote(text, match_position):
    """Check if a match position is within a footnote."""
    start_check = max(0, match_position - 500)
    text_before = text[start_check:match_position]
    text_after = text[match_position:match_position + 200]

    if re.search(r'Return to text', text_before, re.IGNORECASE):
        if not re.search(r'Return to text', text_after, re.IGNORECASE):
            return True

    if re.search(r'\[\d+\]', text_before):
        return True

    if re.search(r'\d+\.\s+[A-Z]', text_before[-100:]):
        return True

    return False

def clean_text_minutes(text, date):
    """Clean text for FOMC minutes based on date."""
    text = fix_text_encoding(text)

    if date == pd.Timestamp('2021-11-03'):
        start_pattern = r'The manager turned first to a discussion'
        match = re.search(start_pattern, text, re.IGNORECASE)
        if match:
            sentence_start = text.rfind('.', 0, match.start())
            if sentence_start == -1:
                sentence_start = 0
            else:
                sentence_start += 1
            text = text[sentence_start:].strip()
    elif date < pd.Timestamp('2019-01-01'):
        pattern = r'Manager of the System Open'
        matches = list(re.finditer(pattern, text, re.IGNORECASE))
        if matches:
            match = matches[0]
            sentence_end = text.find('.', match.end())
            if sentence_end != -1:
                text = text[sentence_end + 1:].strip()
    else:
        pattern = r'Developments in Financial Markets and Open Market Operations'
        matches = list(re.finditer(pattern, text, re.IGNORECASE))
        if matches:
            selected_match = None
            for match in matches:
                if not is_in_footnote(text, match.start()):
                    selected_match = match
                    break
            if selected_match is None:
                selected_match = matches[0]
            sentence_end = text.find('.', selected_match.end())
            if sentence_end != -1:
                text = text[sentence_end + 1:].strip()

    end_pattern = r'meeting adjourned'
    match = re.search(end_pattern, text, re.IGNORECASE)
    if match:
        sentence_start = text.rfind('.', 0, match.start())
        if sentence_start == -1:
            sentence_start = 0
        text = text[:sentence_start].strip()

    return text.strip()

print("\nCleaning minutes...")
cleaned_texts = []

for idx, row in df.iterrows():
    if idx % 20 == 0:
        print(f"Processing minutes {idx+1}/{len(df)}...")
    date = row['date']
    text = row['text']
    cleaned_text = clean_text_minutes(text, date)
    cleaned_texts.append(cleaned_text)

df_cleaned = df.copy()
df_cleaned['text'] = cleaned_texts
df_cleaned['date'] = df_cleaned['date'].dt.strftime('%Y-%m-%d')

output_file = os.path.join(output_dir, 'fomc_minutes_cleaned.csv')
df_cleaned.to_csv(output_file, index=False)

print(f"\nCleaned minutes saved to: {output_file}")
print(f"Total minutes: {len(df_cleaned)}")

print("\n" + "="*70)
print("CLEANING STATISTICS")
print("="*70)

original_lengths = df['text'].str.len()
cleaned_lengths = df_cleaned['text'].str.len()

print(f"\nAverage original text length: {original_lengths.mean():.0f} characters")
print(f"Average cleaned text length: {cleaned_lengths.mean():.0f} characters")
print(f"Average reduction: {(original_lengths.mean() - cleaned_lengths.mean()):.0f} characters ({((1 - cleaned_lengths.mean()/original_lengths.mean())*100):.1f}%)")

print("\n" + "="*70)
print("EXAMPLES OF CLEANED TEXT")
print("="*70)

pre_2019_example = df_cleaned[df_cleaned['date'] < '2019-01-01'].iloc[-1] if len(df_cleaned[df_cleaned['date'] < '2019-01-01']) > 0 else None
if pre_2019_example is not None:
    print(f"\nPRE-2019 PERIOD")
    print(f"Date: {pre_2019_example['date']}")
    print(f"First 200 characters: {pre_2019_example['text'][:200]}...")

post_2019_example = df_cleaned[df_cleaned['date'] >= '2019-01-01'].iloc[0] if len(df_cleaned[df_cleaned['date'] >= '2019-01-01']) > 0 else None
if post_2019_example is not None:
    print(f"\n2019 ONWARD PERIOD")
    print(f"Date: {post_2019_example['date']}")
    print(f"First 200 characters: {post_2019_example['text'][:200]}...")

print("\n" + "="*70)
print("SHORTEST 5 ENTRIES (FOR INSPECTION)")
print("="*70)

df_cleaned['text_length'] = df_cleaned['text'].str.len()
shortest_5 = df_cleaned.nsmallest(5, 'text_length')[['id', 'date', 'text_length', 'text']]

for idx, row in shortest_5.iterrows():
    print(f"\n{'-'*70}")
    print(f"ID: {row['id']}")
    print(f"Date: {row['date']}")
    print(f"Length: {row['text_length']} characters")
    print(f"\nFull text:")
    print(row['text'][:1000])
    if row['text_length'] > 1000:
        print(f"\n... (truncated, {row['text_length'] - 1000} more characters)")

print("\n" + "="*70)
print("Cleaning complete!")
# Out:
# Reading FOMC minutes...
# Loaded 199 minutes
#
# Cleaning minutes...
# Processing minutes 1/199...
# Processing minutes 21/199...
# Processing minutes 41/199...
# Processing minutes 61/199...
# Processing minutes 81/199...
# Processing minutes 101/199...
# Processing minutes 121/199...
# Processing minutes 141/199...
# Processing minutes 161/199...
# Processing minutes 181/199...
#
# Cleaned minutes saved to: /content/drive/MyDrive/FedComs/Minutes/fomc_minutes_cleaned.csv
# Total minutes: 199
#
# ======================================================================
# CLEANING STATISTICS
# ======================================================================
#
# Average original text length: 47193 characters
# Average cleaned text length: 39751 characters
# Average reduction: 7442 characters (15.8%)
#
# ======================================================================
# EXAMPLES OF CLEANED TEXT
# ======================================================================
#
# PRE-2019 PERIOD
# Date: 2018-12-19
# First 200 characters: Minutes of the Federal Open Market Committee
# December 18-19, 2018
# A joint meeting of the Federal Open Market Committee and the Board of Governors was held in the offices of the Board of Governors of t...
#
# 2019 ONWARD PERIOD
# Date: 2019-01-30
# First 200 characters: S. and global financial markets. Financial markets were quite volatile over the intermeeting period. Market participants pointed to a number of factors as contributing to the heightened volatility and...
#
# ======================================================================
# SHORTEST 5 ENTRIES (FOR INSPECTION)
# ======================================================================
#
# ----------------------------------------------------------------------
# ID: minutes_20050809
# Date: 2005-08-09
# Length: 17993 characters
#
# Full text:
# There were no open market operations in foreign currencies for the System's account in the period since the previous meeting. The Manager also reported on developments in domestic financial markets and on System open market transactions in government securities and federal agency obligations during the period since the previous meeting. By unanimous vote, the Committee ratified these transactions. The information received at this meeting suggested that final demand had expanded at a solid pace in the second quarter, led by a surge in net exports and another robust gain in residential investment, while business investment and consumer spending rose at moderate rates. The labor market continued to improve gradually in June and July. Core CPI and PCE prices decelerated in recent months, after notable increases earlier in the year. Crude oil prices continued to rise, reaching record levels in nominal terms over the intermeeting period. Payroll employment grew in June and July at a pace tha
#
# ... (truncated, 16993 more characters)
#
# ----------------------------------------------------------------------
# ID: minutes_20021210
# Date: 2002-12-10
# Length: 19392 characters
#
# Full text:
# There were no open market operations in foreign currencies for the System's account in the period since the previous meeting. The Manager also reported on developments in domestic financial markets and on System open market transactions in government securities and securities issued or fully guaranteed by federal agencies during the period November 6, 2002, through December 9, 2002. By unanimous vote, the Committee ratified these transactions. The Committee then turned to a discussion of the economic and financial outlook and the conduct of monetary policy over the intermeeting period ahead. The information reviewed at this meeting suggested that economic growth had been sluggish on balance since midsummer. Housing demand remained strong, but business fixed investment was still in the doldrums and consumer spending had flagged in late summer before apparently picking up somewhat in the autumn. Payroll employment had changed little since midyear, and industrial production still seemed t
#
# ... (truncated, 18392 more characters)
#
# ----------------------------------------------------------------------
# ID: minutes_20050920
# Date: 2005-09-20
# Length: 19409 characters
#
# Full text:
# There were no open market operations in foreign currencies for the System's account in the period since the previous meeting. The Manager also reported on developments in domestic financial markets and on System open market transactions in government securities and federal agency obligations during the period since the previous meeting. By unanimous vote, the Committee ratified these transactions. The information reviewed at this meeting suggested that, before the landfall of Hurricane Katrina on the Gulf Coast, expansion of economic activity had been solid, led by robust gains in housing and buoyant consumer spending. While business investment appeared to be losing some momentum, labor markets continued to improve, and increases in core CPI and PCE prices were modest after notable increases earlier in the year. Only limited data bearing on the likely economic effects of the hurricane were available. Oil and gasoline prices, however, were on the rise, spiking to record levels in the da
#
# ... (truncated, 18409 more characters)
#
# ----------------------------------------------------------------------
# ID: minutes_20060131
# Date: 2006-01-31
# Length: 19480 characters
#
# Full text:
# There were no open market operations in foreign currencies for the System's account in the period since the previous meeting. The Manager also reported on developments in domestic financial markets and on System open market transactions in government securities and federal agency obligations during the period since the previous meeting. By unanimous vote, the Committee ratified these transactions. The information reviewed at this meeting suggested that underlying growth in aggregate demand remained solid, even though the expansion of real GDP was estimated to have slowed in the fourth quarter. Household spending rose smartly, outside of autos, and orders and shipments of nondefense capital goods in the business sector were generally quite strong. Housing markets showed some signs of cooling, but starts and sales remained at high levels. Industrial production posted moderate gains, even after excluding hurricane-related rebounds in some production categories, and private payrolls expand
#
# ... (truncated, 18480 more characters)
#
# ----------------------------------------------------------------------
# ID: minutes_20051213
# Date: 2005-12-13
# Length: 19999 characters
#
# Full text:
# There were no open
# market operations in foreign currencies for the System's account in the
# period since the previous meeting. The Manager also reported on developments
# in domestic financial markets and on System open market transactions in
# government securities and federal agency obligations during the period
# since the previous meeting. By unanimous vote, the Committee ratified
# these transactions. The information reviewed at this meeting suggested that the economy
# continued to expand at a solid rate in the fourth quarter. Industrial
# production rebounded, and employment growth appeared to have recovered
# smartly from the depressing effects of recent hurricanes. Although some
# scattered signs of cooling of the housing sector had emerged, the pace
# of construction activity and sales remained brisk. More broadly, spending
# by consumers and businesses was well maintained. Core consumer price inflation
# remained subdued, even though some of the increase in energy costs had
# apparently passed throu
#
# ... (truncated, 18999 more characters)
#
# ======================================================================
# Cleaning complete!
